# %% [markdown]
# ## Ints and Floats

# %%
20 / 4
# Out:
# 5.0

# %%
4 + 4.0
# Out:
# 8.0

# %%
4 * 4.0
# Out:
# 16.0

# %%
4 ** 4.0
# Out:
# 256.0

# %%
int(4 ** 4.0)
# Out:
# 256

# %%
int(8.9)
# Out:
# 8

# %%
int(8.99999999)
# Out:
# 8

# %%
int(14/3)
# Out:
# 4

# %%
round(14/3, 2)
# Out:
# 4.67

# %%
1.2 - 1.0
# Out:
# 0.19999999999999996

# %%
14/3
# Out:
# 4.666666666666667

# %%
round(1.2 - 1.0, 2)
# Out:
# 0.2
